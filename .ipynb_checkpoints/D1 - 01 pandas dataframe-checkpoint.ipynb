# %%
print("hello world")
# Out:
# hello world

# %%
import sys

# %%
sys.version
# Out:
# '3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 12:04:33) \n[GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]'

# %%
import pandas as pd

# %%
#df = pd.read_csv("https://raw.githubusercontent.com/abulbasar/data/master/insurance.csv")

df = pd.read_csv("/data/insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1338, 7)

# %%
nrows = df.shape[0]
nrows
# Out:
# 1338

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %% [markdown]
# # What we can do with a dataframe?
#
# - explore the data set
#     - number of rows
#     - number of columns
#     - column types
# - Check whether you have null values or not
# - Handle null values
# - Filter data frame based on the index
# - Filter the dataframe based on column name
# - Filter the dataframe based on conditions
# - Group the data frame based on one more columns and aggregate
# - Sort the data frame
# - Replce some values in the dataframe
# - Add a new column to the dataframe
# - Join two dataframes
# - Sample

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.sample(10)
# Out:
#       age     sex    bmi  children smoker     region      charges
# 377    24    male  40.15         0    yes  southeast  38126.24650
# 447    56  female  25.65         0     no  northwest  11454.02150
# 236    18  female  26.73         0     no  southeast   1615.76670
# 320    34    male  25.27         1     no  northwest   4894.75330
# 638    39    male  26.41         0    yes  northeast  20149.32290
# 803    18  female  42.24         0    yes  southeast  38792.68560
# 1127   35  female  35.86         2     no  southeast   5836.52040
# 1273   35    male  27.61         1     no  southeast   4747.05290
# 847    23    male  50.38         1     no  southeast   2438.05520
# 1139   19  female  32.49         0    yes  northwest  36898.73308

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df = pd.read_csv("/data/mobile-sales-data.csv")
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# Country      10 non-null object
# Age          9 non-null float64
# Salary       9 non-null float64
# Purchased    10 non-null object
# dtypes: float64(2), object(2)
# memory usage: 400.0+ bytes

# %%
df.isnull()
# Out:
#    Country    Age  Salary  Purchased
# 0    False  False   False      False
# 1    False  False   False      False
# 2    False  False   False      False
# 3    False  False   False      False
# 4    False  False    True      False
# 5    False  False   False      False
# 6    False   True   False      False
# 7    False  False   False      False
# 8    False  False   False      False
# 9    False  False   False      False

# %%
df.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df.isnull().sum(axis = 1)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# 5    0
# 6    1
# 7    0
# 8    0
# 9    0
# dtype: int64

# %%
df.fillna(df.mean())
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df.mean()
# Out:
# Age          38.777778
# Salary    63777.777778
# dtype: float64

# %%
df.fillna({"Age": -1, "Salary": 999})
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0    999.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  -1.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df = df.fillna(df.mean())

# %%
df
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df = pd.read_csv("/data/insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.iloc[-5:, -2:]
# Out:
#          region     charges
# 1333  northwest  10600.5483
# 1334  northeast   2205.9808
# 1335  southeast   1629.8335
# 1336  southwest   2007.9450
# 1337  northwest  29141.3603

# %%
df[["region", "charges"]]
# Out:
#          region      charges
# 0     southwest  16884.92400
# 1     southeast   1725.55230
# 2     southeast   4449.46200
# 3     northwest  21984.47061
# 4     northwest   3866.85520
# 5     southeast   3756.62160
# 6     southeast   8240.58960
# 7     northwest   7281.50560
# 8     northeast   6406.41070
# 9     northwest  28923.13692
# 10    northeast   2721.32080
# 11    southeast  27808.72510
# 12    southwest   1826.84300
# 13    southeast  11090.71780
# 14    southeast  39611.75770
# 15    southwest   1837.23700
# 16    northeast  10797.33620
# 17    northeast   2395.17155
# 18    southwest  10602.38500
# 19    southwest  36837.46700
# 20    northeast  13228.84695
# 21    southwest   4149.73600
# 22    southeast   1137.01100
# 23    northeast  37701.87680
# 24    northwest   6203.90175
# 25    southeast  14001.13380
# 26    northeast  14451.83515
# 27    northwest  12268.63225
# 28    northwest   2775.19215
# 29    southwest  38711.00000
# ...         ...          ...
# ...

# %%
df.loc[:, ["region", "charges"]]
# Out:
#          region      charges
# 0     southwest  16884.92400
# 1     southeast   1725.55230
# 2     southeast   4449.46200
# 3     northwest  21984.47061
# 4     northwest   3866.85520
# 5     southeast   3756.62160
# 6     southeast   8240.58960
# 7     northwest   7281.50560
# 8     northeast   6406.41070
# 9     northwest  28923.13692
# 10    northeast   2721.32080
# 11    southeast  27808.72510
# 12    southwest   1826.84300
# 13    southeast  11090.71780
# 14    southeast  39611.75770
# 15    southwest   1837.23700
# 16    northeast  10797.33620
# 17    northeast   2395.17155
# 18    southwest  10602.38500
# 19    southwest  36837.46700
# 20    northeast  13228.84695
# 21    southwest   4149.73600
# 22    southeast   1137.01100
# 23    northeast  37701.87680
# 24    northwest   6203.90175
# 25    southeast  14001.13380
# 26    northeast  14451.83515
# 27    northwest  12268.63225
# 28    northwest   2775.19215
# 29    southwest  38711.00000
# ...         ...          ...
# ...

# %%
df[df.region == "northeast"].sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 852    46  female  35.530         0    yes  northeast  42111.66470
# 121    18    male  23.750         0     no  northeast   1705.62450
# 738    23    male  31.730         3    yes  northeast  36189.10170
# 828    41    male  30.780         3    yes  northeast  39597.40720
# 874    44    male  21.850         3     no  northeast   8891.13950
# 690    21    male  27.360         0     no  northeast   2104.11340
# 528    46    male  39.425         1     no  northeast   8342.90875
# 633    40    male  22.705         2     no  northeast   7173.35995
# 637    35  female  38.095         2     no  northeast  24915.04626
# 1290   38  female  19.950         2     no  northeast   7133.90250

# %%
df[df["region"] == "northeast"].sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1208   37  female  25.555         1    yes  northeast  20296.86345
# 573    62  female  36.860         1     no  northeast  31620.00106
# 185    36    male  41.895         3    yes  northeast  43753.33705
# 623    18    male  33.535         0    yes  northeast  34617.84065
# 366    56  female  32.300         3     no  northeast  13430.26500
# 1188   43  female  25.270         1    yes  northeast  21771.34230
# 1178   23  female  34.865         0     no  northeast   2899.48935
# 1098   52  female  30.875         0     no  northeast  23045.56616
# 637    35  female  38.095         2     no  northeast  24915.04626
# 1212   18    male  21.470         0     no  northeast   1702.45530

# %%
df.query("region == 'northeast'")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 8      37    male  29.830         2     no  northeast   6406.41070
# 10     25    male  26.220         0     no  northeast   2721.32080
# 16     52  female  30.780         1     no  northeast  10797.33620
# 17     23    male  23.845         0     no  northeast   2395.17155
# 20     60  female  36.005         0     no  northeast  13228.84695
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 26     63  female  23.085         0     no  northeast  14451.83515
# 31     18  female  26.315         0     no  northeast   2198.18985
# 38     35    male  36.670         1    yes  northeast  39774.27630
# 40     24  female  26.600         0     no  northeast   3046.06200
# 44     38    male  37.050         1     no  northeast   6079.67150
# 46     18  female  38.665         2     no  northeast   3393.35635
# 50     18  female  35.625         0     no  northeast   2211.13075
# ...

# %%
df.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 267    59  female  32.395         3     no  northeast  14590.63205
# 1122   53  female  36.860         3    yes  northwest  46661.44240
# 60     43    male  27.360         3     no  northeast   8606.21740
# 44     38    male  37.050         1     no  northeast   6079.67150
# 1271   25  female  34.485         0     no  northwest   3021.80915
# 715    60    male  28.900         0     no  southwest  12146.97100
# 280    40  female  28.120         1    yes  northeast  22331.56680
# 1306   29  female  21.850         0    yes  northeast  16115.30450
# 36     62  female  32.965         3     no  northwest  15612.19335
# 395    46    male  19.855         0     no  northwest   7526.70645

# %%
df.groupby("region").charges.mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
import numpy as np

# %%
df.groupby("region").charges.agg([np.mean, np.median])
# Out:
#                    mean        median
# region
# northeast  13406.384516  10057.652025
# northwest  12417.575374   8965.795750
# southeast  14735.411438   9294.131950
# southwest  12346.937377   8798.593000

# %%
df.sort_values("charges", ascending= False)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# 1146   60    male  32.800         0    yes  southwest  52590.82939
# 34     28    male  36.400         1    yes  southwest  51194.55914
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 1062   59    male  41.140         1    yes  southeast  48970.24760
# 488    44  female  38.060         0    yes  southeast  48885.13561
# 175    63  female  37.700         0    yes  southwest  48824.45000
# 530    57    male  42.130         1    yes  southeast  48675.51770
# 901    60    male  40.920         0    yes  southeast  48673.55880
# ...

# %%
pd.merge?

# %%
movies = pd.read_csv("/data/ml-latest-small/movies.csv")
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv("/data/ml-latest-small/ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# # Exercise:
#
# Find top 10 movies based on highest average rating.
# The top 10 movies must have at least 100 ratings.
# Display movie Id, title, and avg rating.
#
# movies: movies.csv
# ratings: ratings.csv
#
# Location of the data:
# https://github.com/abulbasar/data/tree/master/ml-latest-small
